# %% [markdown]
# <h2>Soal 1: Hello World to Python</h2>
#
# Print Say Hello World to Python

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# Expected Output :
#
# Hello World Python

# %% [markdown]
# <h2>Soal 2: Aritmatika di Python </h2>
#
# - Buat statement pertambahan antara 2 number di Python
# - Buat statement perkurangan antara 2 number di Python
# - Buat statement perkalian antara 2 number di Python
# - Buat statement pembagian antara 2 number di Python

# %%
# Membuat variable utama
a = 4
b = 8

# Membuat variabel operasi matematis
c = a+b
d = b-a
e = a*b
f = b/a

print("Berikut adalah contoh pertambahan:", c, '\n'
      "Berikut adalah contoh pengurangan:", d, '\n'
      "Berikut adalah contoh perkalian:", e, '\n'
      "Berikut adalah contoh pembagian:", f)
# Out:
# Berikut adalah contoh pertambahan: 12
# Berikut adalah contoh pengurangan: 4
# Berikut adalah contoh perkalian: 32
# Berikut adalah contoh pembagian: 2.0

# %% [markdown]
# <h2>Quiz 3: Assign Variable dan Tipe Data Integer, Float </h2>
#
# - Buat suatu variabel a dan b, dimana a dan b adalah nilai bertipe data numeric
# - Berikan suatu nilai bertipe data integer, hasil pembagian dari a dengan b
# - Berikan suatu nilai bertipe data float, hasil pembagian dari a dengan b

# %%
a = 100
b = 5

print("Berikut adalah hasil pembagian variabel a dengan b yang memiliki tipe data integer: ", int(a/b))
print("Berikut adalah hasil pembagian variabel a dengan b yang memiliki tipe data float: ", float(a/b))
# Out:
# Berikut adalah hasil pembagian variabel a dengan b yang memiliki tipe data integer:  20
# Berikut adalah hasil pembagian variabel a dengan b yang memiliki tipe data float:  20.0

# %% [markdown]
# <h2>Soal 4: String Operation </h2>
#
# - masukan nama depan kamu kedalam suatu variable firstname
# - masukan nama belakang kamu kedalam suatu variable lasname
# - tampilkan suatu kalimat 'Hello sanbercode, saya firstname lastname! saya siap belajar python data science.'

# %%
firstname = nur
lastname = arifin
print("Hello sanbercode, saya ", firstname, lastname, "! ", "saya siap belajar pyhton data science")

# masalah > NameError: name 'nur' is not defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/23/5tyn84qs0kn9f0f5k8ckqlh00000gn/T/ipykernel_2474/1342479841.py in <module>
# ----> 1 firstname = nur
#       2 lastname = arifin
#       3 print("Hello sanbercode, saya ", firstname, lastname, "! ", "saya siap belajar pyhton data science")
#
# NameError: name 'nur' is not defined

# %% [markdown]
# Expected Output :
#
# Hello sanbercode, saya fauzan taufik! saya siap belajar python data science.

# %% [markdown]
# <h2>Soal 5: Tipe Data</h2>
#
# Lengkapi code di bawah ini untuk menghasilkan output yang sesuai

# %%
p = 9.99999
q = 'the number: '
print(q + str(p))
# Out:
# the number: 9.99999

# %% [markdown]
# Expected Output :
#
# the number: 9.99999
