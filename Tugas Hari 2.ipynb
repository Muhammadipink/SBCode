# %% [markdown]
# <h2>Soal 1: Helper Function</h2>
#
# Jawab Pertanyaan di bawah ini:
#
# Misalkan kamu ingin mengetahui tentang kegunaan fungsi 'len' di Python, maka fungsi apa yang bisa kamu gunakan untuk menolong kamu?

# %%
# lengkapi code ini
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %% [markdown]
# <h2>Soal 2: Built-in Function</h2>
#
# Jawab Pertanyaan di bawah ini:
#
# Apa itu built-in Function?
#
# Sebutkan 3 built-in Function di pyhon!
#
# Berikan contoh masing2 1 cara penggunaan built-in function yang kamu sebutkan sebelumnya

# %% [markdown]
# 1. Apa itu built-in Function?
# > built-in Function adalah fungsi bawaan dari python. Built-in Function pada Python bisa langsung digunakan tanpa perlu membuatnya
#
# 2. Sebutkan 3 built-in Function di pyhon!
# > * Fungsi len()
# > * Fungsi sum()
# > * Fungsi input()

# %%
# 3. Contoh penggunaan built in function

# - Fungsi len()
list = [1,3,5,6,8,9,2,5]
print("Berikut adalah penerapan fungsi len :" , len(list))

# - Fungsi sum()
print("Berikut adalah penerapan fungsi sum :", sum(list))

# - Fungsi input()
nama = input('Masukkan nama Anda:')
print("Berikut adalah penerapan fungsi input :", nama)
# Out:
# Berikut adalah penerapan fungsi len : 8
# Berikut adalah penerapan fungsi sum : 39
# Berikut adalah penerapan fungsi input : Muhammad Nur Arifin

# %% [markdown]
# <h2>Soal 3: Method dan Function</h2>
#
# Jawab Pertanyaan di bawah ini:
#
# - Apa perbedaan method dan function?

# %% [markdown]
# ---
# 1. **Function** adalah sebuah perintah yang bisa digunakan secara berulang (dipanggil berkali-kali) dan dapat dibuat dengan pengaturan tertentu.
# 2. **Method** adalah sebuah fungsi yang dimiliki oleh suatu objek dan hanya bisa diterapkan pada objek tersebut
# ---

# %% [markdown]
# <h2>Soal 4: Menggunkan Method String</h2>
#
# Lengkapi kode untuk menghasilkan suatu output yang di harapkan

# %%
kalimat = "Corona cepat selesai"

# gunakan method untuk mengubah nilai kalimat menjadi uppercase semua kemudian tampilkan hasilnya
print("Bentuk uppercase dari", kalimat , "adalah:", kalimat.upper())

# gunakan method untuk menghitung berapa huruf e di dalam kalimat
print("Jumlah huruf 'e' yang terdapat dalam variabel kalimat adalah: ", kalimat.count('e'))
# Out:
# Bentuk uppercase dari Corona cepat selesai adalah: CORONA CEPAT SELESAI
# Jumlah huruf 'e' yang terdapat dalam variabel kalimat adalah:  3

# %% [markdown]
# Expected Output:
#
# CORONA CEPAT SELESAI
#
# 3

# %% [markdown]
# <h2>Soal 5: Membuat Simple Function</h2>
#
# Buatlah suatu fungsi yang menerima satu input argumen berbentuk list dan mempunyai elemen bertipe numeric semua, dimana fungsi tersebut berguna untuk menghitung rata2 dari kumpulan elemen list tersebut. namai fungsi tersebut 'mean_list'

# %%
obj_list = [11.25, 18.0, 20.0, 10.75, 9.50]
def mean_list(obj_list):
    summing = float(sum(obj_list))
    count = float(len(obj_list))
    if obj_list == []:
        return False
    return float(summing/count)

print(mean_list(obj_list))
# Out:
# 13.9

# %% [markdown]
# Expected Output:
#
# 13.9

# %% [markdown]
# <h2>Soal 6: Membuat Function dengan Multiple arguments</h2>
#
# Buatlah suatu fungsi untuk melakukan penggabungan antara dua list

# %%
obj_list = [2, 4, 5, 6]
obj_penambah = [1, 2, 3]

def kali_list(a, b):
    a = obj_list
    b = obj_penambah
    return a+b
    
    
print(kali_list(obj_list, obj_penambah))
# Out:
# [2, 4, 5, 6, 1, 2, 3]

# %% [markdown]
# Expected Output:
#
# [2, 4, 5, 6, 1, 2, 3]
